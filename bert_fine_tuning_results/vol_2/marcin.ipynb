# %%
import wandb
import matplotlib.pyplot as plt
import torch
import pandas as pd
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForTokenClassification

# %%
wandb.login(key='')
hf_token = ''
api = wandb.Api()

project_name = "bert_selection_single_app_ft"

runs = api.runs(f"sf-kozlowski-university-of-warsaw/{project_name}")
history = runs[0].history()
history.head()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/gustaw/.netrc
#    _step  _runtime  train/loss  train/grad_norm  train/learning_rate  \
# 0      0  6.773655      0.4656         2.192580              0.00002
# 1      1  7.575783      0.2773         1.846480              0.00002
# 2      2  8.391984      0.1695         4.433166              0.00002
# 3      3  9.191858      0.1579         0.882415              0.00002
# 4      4  9.998030      0.0981         1.695973              0.00002
#
#    train/epoch    _timestamp  train/global_step  eval/I-COUPON_recall  \
# 0     0.033113  1.743332e+09                 10                   NaN
# 1     0.066225  1.743332e+09                 20                   NaN
# 2     0.099338  1.743332e+09                 30                   NaN
# 3     0.132450  1.743332e+09                 40                   NaN
# 4     0.165563  1.743332e+09                 50                   NaN
#
#    eval/loss  eval/f1  eval/precision  eval/recall  eval/O_recall  \
# 0        NaN      NaN             NaN          NaN            NaN
# 1        NaN      NaN             NaN          NaN            NaN
# 2        NaN      NaN             NaN          NaN            NaN
# 3        NaN      NaN             NaN          NaN            NaN
# 4        NaN      NaN             NaN          NaN            NaN
#
#    eval/B-COUPON_recall  eval/steps_per_second  eval/overall_accuracy  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    eval/samples_per_second  eval/runtime
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN

# %%
def plot_runs_data(runs, metric):
    plt.figure(figsize=(14, 7))
    for run in runs:
        hist = run.scan_history()
        # Convert to DataFrame
        hist_df = pd.DataFrame(hist)
        if hist_df.empty:
            continue
        if metric in hist_df.columns:
            # Filter out nans
            data = hist_df[metric].dropna()
            labels = list(range(len(data)))
            plt.plot(labels, data, label=f"Run: {run.name}")

    plt.xlabel("Step")
    plt.ylabel(metric)
    plt.title(f"{metric} across Runs")
    plt.legend()
    plt.grid()
    plt.show()

plot_runs_data(runs, "train/loss")
plot_runs_data(runs, "train/grad_norm")
plot_runs_data(runs, "train/learning_rate")
